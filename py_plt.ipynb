# %%
# Assigning a string value to the variable ch
ch = "3.25.15"
# Attempting to convert an invalid string to a float
ch = float(ch)  # Raises ValueError: could not convert string to float
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Assigning a string value to the variable ch
#       2 ch = "3.25.15"
#       3 # Attempting to convert an invalid string to a float
# ----> 4 ch = float(ch)  # Raises ValueError: could not convert string to float
#
# ValueError: could not convert string to float: '3.25.15'

# %%
# Assigning a value to the variable x
x = 20

# Check if x is equal to 1
if x == 1:
    print('X is equal to 1')

# Check if x is equal to 5
elif x == 5:
    print('X is equal to 5')

# Check if x is equal to 10
elif x == 10:
    print('X is equal to 10')

# If none of the above conditions are True
else:
    print('X =', x)
# Out:
# X = 20

# %%
# Break the loop at 'blue'
for x in colors:
    if x =='yellow':
        break
    print(x)
# Prints red green
# Out:
# red
# green
# blue

# %%
# Generate a sequence of numbers from 0 6
# for x in range(7):
#     print(x)
# Prints 0 1 2 3 4 5 6
# You can generate a range of negative numbers as well.
# for x in range(-5,0):
#     print(x)
# # Prints -5 -4 -3 -2 -1
# """The range increments by 1 by default. But, you can specify a different increment by adding a step parameter."""
# # Increment the range with 2
for x in range(2, 10, 2):
    print(x)
# # Prints 2 4 6
# Out:
# 2
# 4
# 6
# 8

# %%
# import random
# Random_integer = random.randint(1,10)
# print(Random_integer)
a=5
b=int

print(a==b)
# Out:
# False

# %%
x = 6
while x:
    print(x)
    x -= 1
# Out:
# 6
# 5
# 4
# 3
# 2
# 1

# %%
x = 1
while x:
    print(x)
    x -= 1
# Out:
# 1

# %%
a="Welcome to the Guess the Number game!\nI'm thinking of a number between 1 and 100. Can you guess what it is?"
print(a)
import random
num = random.randint(1, 100)
while True:
    print("Random Integer:", num)
    guess= input("Enter your guess : ")
    guess=int(guess)
    if  guess==num :
        print("Congratulations! You guessed the number correctly!")
        break
    elif guess<num :
        print("too low!")
    else :
        print("too high!")
# Out:
# Welcome to the Guess the Number game!
# I'm thinking of a number between 1 and 100. Can you guess what it is?
# Random Integer: 34
# too high!
# Random Integer: 34
# too low!
# Random Integer: 34
# Congratulations! You guessed the number correctly!
